# %% [markdown]
# # Import libraries

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler

from keras.layers import Dense
from keras.models import Sequential

import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %% [markdown]
# # Import data

# %%
# CO2, Temperature and Humidity values measured every minute in the greenhouse
df = pd.read_csv('data_week.csv', index_col=0)
df.head()
# Out:
#                      CO2 (ppm)  Temperature (C)  Humidity (%)
# Date Time
# 2023-03-16 11:35:30        456            22.67         31.21
# 2023-03-16 11:36:30        438            21.58         33.16
# 2023-03-16 11:37:30        445            21.19         33.38
# 2023-03-16 11:38:30        446            21.09         32.49
# 2023-03-16 11:39:30        446            21.02         33.16

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 11688 entries, 2023-03-16 11:35:30 to 2023-03-24 14:20:12
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   CO2 (ppm)        11688 non-null  int64
#  1   Temperature (C)  11688 non-null  float64
#  2   Humidity (%)     11688 non-null  float64
# dtypes: float64(2), int64(1)
# memory usage: 365.2+ KB

# %%
df.describe()
# Out:
#           CO2 (ppm)  Temperature (C)  Humidity (%)
# count  11688.000000     11688.000000  11688.000000
# mean     588.642796        22.127713     45.067269
# std      241.142252         1.482375      7.819816
# min      383.000000        18.630000     25.750000
# 25%      423.000000        21.170000     40.607500
# 50%      471.000000        22.290000     45.135000
# 75%      671.000000        23.210000     49.670000
# max     1587.000000        25.210000     70.520000

# %% [markdown]
# # Visualization

# %%
df.plot(figsize=(11, 9), subplots=True, grid=True)
plt.xticks(rotation=90);

# %%
# columns correlation
plt.figure(figsize=(5,4))
sns.heatmap(df.corr().abs());

# %%
# change in last one hour
df[-60:].plot(figsize=(11, 9), subplots=True, marker='o', linestyle='-', grid=True)
plt.xticks(rotation=90);

# %% [markdown]
# # Data preprocessing

# %%
# rename columns
df = df.rename(columns={'CO2 (ppm)':'CO2','Temperature (C)':'Temperature','Humidity (%)':'Humidity'})

# %%
# drop the variables into the same range for the model works well
scaler = MinMaxScaler()
df = pd.DataFrame(scaler.fit_transform(df.values), index=df.index, columns=df.columns)

# %%
# drop the last value and save X variable
X = df.drop(df.index[-1])

# get all value except first value and save Y variable
Y = pd.DataFrame(df.values[1:], index=df.index[:-1], columns=['Y_CO2','Y_Temperature','Y_Humidity'])

# %%
# prepared data view
pd.concat([X,Y], axis=1)
# Out:
#                           CO2  Temperature  Humidity     Y_CO2  Y_Temperature  \
# Date Time
# 2023-03-16 11:35:30  0.060631     0.613982  0.121957  0.045681       0.448328
# 2023-03-16 11:36:30  0.045681     0.448328  0.165513  0.051495       0.389058
# 2023-03-16 11:37:30  0.051495     0.389058  0.170427  0.052326       0.373860
# 2023-03-16 11:38:30  0.052326     0.373860  0.150547  0.052326       0.363222
# 2023-03-16 11:39:30  0.052326     0.363222  0.165513  0.051495       0.367781
# ...                       ...          ...       ...       ...            ...
# 2023-03-24 14:15:12  0.084718     0.223404  0.332365  0.087209       0.218845
# 2023-03-24 14:16:12  0.087209     0.218845  0.333259  0.086379       0.217325
# 2023-03-24 14:17:12  0.086379     0.217325  0.371007  0.089701       0.214286
# 2023-03-24 14:18:12  0.089701     0.214286  0.374805  0.078904       0.211246
# 2023-03-24 14:19:12  0.078904     0.211246  0.402725  0.073920       0.214286
#
#                      Y_Humidity
# Date Time
# 2023-03-16 11:35:30    0.165513
# 2023-03-16 11:36:30    0.170427
# 2023-03-16 11:37:30    0.150547
# 2023-03-16 11:38:30    0.165513
# 2023-03-16 11:39:30    0.140719
# ...                         ...
# 2023-03-24 14:15:12    0.333259
# 2023-03-24 14:16:12    0.371007
# 2023-03-24 14:17:12    0.374805
# 2023-03-24 14:18:12    0.402725
# 2023-03-24 14:19:12    0.420147
#
# [11687 rows x 6 columns]

# %%
# split to train and test
X_train, X_test, y_train, y_test = train_test_split(X.values, Y.values, test_size=0.3, shuffle=False)

print(X_train.shape, y_train.shape, X_test.shape, y_test.shape)
# Out:
# (8180, 3) (8180, 3) (3507, 3) (3507, 3)

# %% [markdown]
# # Model building

# %%
# 1D Convolutional Neural Network Model
model = Sequential([
    Dense(64, input_shape=(3,), activation='relu'),
    Dense(32, activation='relu'),
    Dense(3)
])

# %%
# compile
model.compile(optimizer='adam', loss='mae')

# %%
# model fitting
history = model.fit(X_train, y_train, epochs=50, validation_data=(X_test, y_test))
# Out:
# Epoch 1/50
# 256/256 [==============================] - 2s 3ms/step - loss: 0.0492 - val_loss: 0.0132
# Epoch 2/50
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0099 - val_loss: 0.0131
# Epoch 3/50
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0098 - val_loss: 0.0117
# Epoch 4/50
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0095 - val_loss: 0.0111
# Epoch 5/50
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0094 - val_loss: 0.0126
# Epoch 6/50
# 256/256 [==============================] - 0s 2ms/step - loss: 0.0093 - val_loss: 0.0114
# Epoch 7/50
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0095 - val_loss: 0.0117
# Epoch 8/50
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0094 - val_loss: 0.0126
# Epoch 9/50
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0092 - val_loss: 0.0117
# Epoch 10/50
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0093 - val_loss: 0.0115
# Epoch 11/50
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0093 - val_loss: 0.0123
# Epoch 12/50
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0093 - val_loss: 0.0120
# Epoch 13/50
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0094 - val_loss: 0.0122
# Epoch 14/50
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0094 - val_loss: 0.0121
# Epoch 15/50
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0094 - val_loss: 0.0110
# Epoch 16/50
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0094 - val_loss: 0.0116
# Epoch 17/50
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0092 - val_loss: 0.0123
# Epoch 18/50
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0092 - val_loss: 0.0112
# Epoch 19/50
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0093 - val_loss: 0.0120
# Epoch 20/50
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0092 - val_loss: 0.0127
# Epoch 21/50
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0093 - val_loss: 0.0114
# Epoch 22/50
# 256/256 [==============================] - 1s 3ms/step - loss: 0.0095 - val_loss: 0.0121
# Epoch 23/50
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0092 - val_loss: 0.0116
# Epoch 24/50
# 256/256 [==============================] - 1s 3ms/step - loss: 0.0091 - val_loss: 0.0119
# Epoch 25/50
# 256/256 [==============================] - 1s 3ms/step - loss: 0.0093 - val_loss: 0.0116
# Epoch 26/50
# 256/256 [==============================] - 1s 3ms/step - loss: 0.0093 - val_loss: 0.0111
# Epoch 27/50
# 256/256 [==============================] - 1s 3ms/step - loss: 0.0092 - val_loss: 0.0130
# Epoch 28/50
# 256/256 [==============================] - 1s 3ms/step - loss: 0.0092 - val_loss: 0.0126
# Epoch 29/50
# 256/256 [==============================] - 1s 3ms/step - loss: 0.0092 - val_loss: 0.0113
# Epoch 30/50
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0092 - val_loss: 0.0113
# Epoch 31/50
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0092 - val_loss: 0.0120
# Epoch 32/50
# 256/256 [==============================] - 1s 3ms/step - loss: 0.0092 - val_loss: 0.0126
# Epoch 33/50
# 256/256 [==============================] - 1s 3ms/step - loss: 0.0093 - val_loss: 0.0116
# Epoch 34/50
# 256/256 [==============================] - 1s 3ms/step - loss: 0.0091 - val_loss: 0.0117
# Epoch 35/50
# 256/256 [==============================] - 1s 3ms/step - loss: 0.0092 - val_loss: 0.0111
# Epoch 36/50
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0092 - val_loss: 0.0112
# Epoch 37/50
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0091 - val_loss: 0.0122
# Epoch 38/50
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0094 - val_loss: 0.0116
# Epoch 39/50
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0091 - val_loss: 0.0112
# Epoch 40/50
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0091 - val_loss: 0.0110
# Epoch 41/50
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0092 - val_loss: 0.0119
# Epoch 42/50
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0091 - val_loss: 0.0113
# Epoch 43/50
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0092 - val_loss: 0.0116
# Epoch 44/50
# 256/256 [==============================] - 1s 3ms/step - loss: 0.0091 - val_loss: 0.0120
# Epoch 45/50
# 256/256 [==============================] - 1s 3ms/step - loss: 0.0092 - val_loss: 0.0110
# Epoch 46/50
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0092 - val_loss: 0.0116
# Epoch 47/50
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0092 - val_loss: 0.0117
# Epoch 48/50
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0091 - val_loss: 0.0118
# Epoch 49/50
# 256/256 [==============================] - 1s 3ms/step - loss: 0.0091 - val_loss: 0.0109
# Epoch 50/50
# 256/256 [==============================] - 1s 3ms/step - loss: 0.0091 - val_loss: 0.0120

# %%
plt.figure(figsize=(11,3))
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.grid()
plt.legend(['train', 'validation'], loc='upper right')
plt.show()

# %%
# save model
model.save("models/ann.h5")

# %%
# prediction
pred = model.predict(X_test)
# Out:
# 110/110 [==============================] - 0s 1ms/step

# %%
# MinMaxScaler inverse transform
pred = scaler.inverse_transform(pred)
y_test = scaler.inverse_transform(y_test)

# %% [markdown]
# # Evaluation

# %%
print('Mean absolute error:',mean_absolute_error(y_test, pred))
print('Mean squared error:',mean_squared_error(y_test, pred))
print('Root mean squared error:',mean_squared_error(y_test, pred)**(1/2))
# Out:
# Mean absolute error: 1.4699390606517166
# Mean squared error: 8.52685945796958
# Root mean squared error: 2.9200786732500172

# %%
print('Coefficient of determination (r2 score):',r2_score(y_test, pred))
# Out:
# Coefficient of determination (r2 score): 0.9872773861066766

# %%
plt.figure(figsize=(11,3))
plt.plot(y_test[:,0])
plt.plot(pred[:,0])
plt.title('CO2')
plt.grid()
plt.legend(['real', 'predicted'], loc='upper right')
plt.show()

# %%
plt.figure(figsize=(11,3))
plt.plot(y_test[:,1])
plt.plot(pred[:,1])
plt.title('Temperature')
plt.grid()
plt.legend(['real', 'predicted'], loc='upper right')
plt.show()

# %%
plt.figure(figsize=(11,3))
plt.plot(y_test[:,2])
plt.plot(pred[:,2])
plt.title('Humidity')
plt.grid()
plt.legend(['real', 'predicted'], loc='upper right')
plt.show()
